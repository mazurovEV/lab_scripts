# %%
import pandas as pd
import subprocess
import re
import os
import matplotlib.pyplot as plt
import shutil
from multiprocessing import Pool

# %%
#!!TODO: возможно надо делать меньше порог на p-value

# %%
d = pd.read_csv("../all_marks/ChiP-Seq_for_all_marks_all_replicas.tsv", sep='\t', index_col=False)

# %%
#macs2 filterdup -i CTCF_ChIP_200K.bed.gz --keep-dup=1 -o CTCF_ChIP_200K_filterdup.bed
#macs2 filterdup -i CTCF_ChIP_200K_control.bed.gz --keep-dup=1 -o CTCF_ChIP_200K_control_filterdup.bed
#macs2 predictd -i CTCF_ChIP_200K_filterdup.bed -g hs -m 5 50
#macs2 pileup -i CTCF_ChIP_200K_filterdup.bed -o CTCF_ChIP_200K_filterdup.pileup.bdg --extsize 254
#macs2 pileup -i CTCF_Control_200K_filterdup.bed -B --extsize 127 -o d_bg.bdg
#macs2 pileup -i CTCF_Control_200K_filterdup.bed -B --extsize 500 -o 1k_bg.bdg
#macs2 bdgopt -i 1k_bg.bdg -m multiply -p 0.254 -o 1k_bg_norm.bdg
#macs2 pileup -i CTCF_Control_200K_filterdup.bed -B --extsize 5000 -o 10k_bg.bdg
#macs2 bdgopt -i 1k_bg.bdg -m multiply -p 0.0254 -o 1k_bg_norm.bdg
#macs2 bdgcmp -m max -t 1k_bg_norm.bdg -c 10k_bg_norm.bdg -o 1k_10k_bg_norm.bdg
#macs2 bdgcmp -m max -t 1k_10k_bg_norm.bdg -c d_bg.bdg -o d_1k_10k_bg_norm.bdg
#macs2 bdgopt -i d_1k_10k_bg_norm.bdg -m max -p .0188023 -o local_bias_raw.bdg
#macs2 bdgopt -i local_bias_raw.bdg -m multiply -p .99858 -o local_lambda.bdg
#macs2 bdgcmp -t CTCF_ChIP_200K_filterdup.pileup.bdg -c local_lambda.bdg -m qpois -o CTCF_ChIP_200K_qvalue.bdg
#macs2 bdgbroadcall -i CTCF_ChIP_200K_qvalue.bdg -c 1.301 -l 245 -g 100 -o CTCF_ChIP_200K_peaks.bed
#or& for narrow peaks:
#macs2 bdgpeakcall -i CTCF_ChIP_200K_qvalue.bdg -c 1.301 -l 245 -g 100 -o CTCF_ChIP_200K_peaks.bed
def callPeaks(data):
    signal = data[0]
    signal_path = data[1]
    control = data[2]
    control_path = data[3]
    norm_factor = data[4]
    tmp_dir = "/data/mazurovev/tmp_peaks/tmp_call_peaks_for_" + signal
    os.mkdir(tmp_dir)
    print(signal)
    try:
        output = subprocess.check_output("macs2 filterdup -i " + signal_path + signal + ".bed" + " --keep-dup=1 -o " + tmp_dir + "/" + signal + "_filterdup.bed", shell=True, stderr=subprocess.STDOUT).decode()
        m = re.match(r".+tags after filtering in alignment file: (\d+).+", output, re.MULTILINE|re.DOTALL)
        signal_reads_count = m.group(1)
        
        output = subprocess.check_output("macs2 filterdup -i " + control_path + control + ".bed" + " --keep-dup=1 -o " + tmp_dir + "/" + control + "_filterdup.bed", shell=True, stderr=subprocess.STDOUT).decode()
        m = re.match(r".+tags after filtering in alignment file: (\d+).+", output, re.MULTILINE|re.DOTALL)
        control_reads_count = m.group(1)
        
        output = subprocess.check_output("macs2 predictd -i " + tmp_dir + "/" + signal + "_filterdup.bed" + " -g hs -m 5 50", shell=True, stderr=subprocess.STDOUT).decode()
        m = re.match(r".+predicted fragment length is (\d+).+", output, re.MULTILINE|re.DOTALL)
        extsize = m.group(1)
        
        output = subprocess.check_output("macs2 pileup -i " + tmp_dir + "/" + signal + "_filterdup.bed" + " -f BED -o " + tmp_dir + "/" + signal + "_filterdup.pileup.bdg --extsize " + extsize, shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 pileup -i " + tmp_dir + "/" + control + "_filterdup.bed" + " -B -f BED --extsize " + str(int(extsize)//2) + " -o " + tmp_dir + "/" + control + "_d_bg.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 pileup -i " + tmp_dir + "/" + control + "_filterdup.bed" + " -B -f BED --extsize 500 -o " + tmp_dir + "/" + control + "_1k_bg.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgopt -i " + tmp_dir + "/" + control + "_1k_bg.bdg" + " -m multiply -p " + str(int(extsize)/1000) + " -o " + tmp_dir + "/" + control + "_1k_bg_norm.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 pileup -i " + tmp_dir + "/" + control + "_filterdup.bed" + " -B -f BED --extsize 5000 -o " + tmp_dir + "/" + control + "_10k_bg.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgopt -i " + tmp_dir + "/" + control + "_10k_bg.bdg" + " -m multiply -p " + str(int(extsize)/10000) + " -o " + tmp_dir + "/" + control + "_10k_bg_norm.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        genome_bg = int(control_reads_count)*int(extsize)/2900000000
        
        output = subprocess.check_output("macs2 bdgcmp -m max -t " + tmp_dir + "/" + control + "_1k_bg_norm.bdg" + " -c " + tmp_dir + "/" + control + "_10k_bg_norm.bdg" + " -o " + tmp_dir + "/" + control + "_1k_10k_bg_norm.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgcmp -m max -t " + tmp_dir + "/" + control + "_1k_10k_bg_norm.bdg" + " -c " + tmp_dir + "/" + control + "_d_bg.bdg" + " -o " + tmp_dir + "/" + control + "_d_1k_10k_bg_norm.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgopt -i " + tmp_dir + "/" + control + "_d_1k_10k_bg_norm.bdg" + " -m max -p " + str(genome_bg) + " -o " + tmp_dir + "/" + control + "_local_bias_raw.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgopt -i " + tmp_dir + "/" + control + "_local_bias_raw.bdg" + " -m multiply -p " + str(norm_factor) + " -o " + tmp_dir + "/" + control + "_local_lambda.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgcmp -t " + tmp_dir + "/" + signal + "_filterdup.pileup.bdg" + " -c " + tmp_dir + "/" + control + "_local_lambda.bdg -m qpois -p 1" + " -o " + tmp_dir + "/" + signal + "_qvalue.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        #broad or narrow peaks
        #output = subprocess.check_output("macs2 bdgbroadcall -i " + tmp_dir + "/" + signal + "_qvalue.bdg" + " -c 1.301 " + " -o " + signal_path + signal + "_peaks.bed", shell=True, stderr=subprocess.STDOUT).decode()
        output = subprocess.check_output("macs2 bdgpeakcall -i " + tmp_dir + "/" + signal + "_qvalue.bdg" + " -c 1.301 -l " + extsize + " -o " + signal_path + signal + "_narrow_peaks.bed", shell=True, stderr=subprocess.STDOUT).decode()
        print("done " + signal)
    except subprocess.CalledProcessError as e:
        output = e.output.decode()
        
    #shutil.rmtree(tmp_dir)
    return output

# %%
def call_peaks_macs2(data):
    signal = data[0]
    signal_path = data[1]
    control = data[2]
    control_path = data[3]
    norm_factor = data[4]
    print("macs2 callpeak -t " + signal_path + signal + ".bed" + 
                                         " -c " + control_path + control + ".bed" + 
                                         " -f BED -g 2.9e9 -q 0.05 -n " + signal + " --ratio " + str(norm_factor))
    try:
        output = subprocess.check_output("macs2 callpeak -t " + signal_path + signal + ".bed" + 
                                         " -c " + control_path + control + ".bed" + 
                                         " -f BED -g 2.9e9 -q 0.05 -n " + signal + " --ratio " + str(norm_factor), shell=True, stderr=subprocess.STDOUT).decode()
    except subprocess.CalledProcessError as e:
        output = e.output.decode()
        
    #shutil.rmtree(tmp_dir)
    return output

# %%
data = []
for index, row in d.iterrows():
    if(row['Experiment target'] == 'H3K27me3-human'):
        signal_path = "/data/mazurovev/" + row['Experiment target'].split('-')[0] + "/" + row['Biosample term id'] + "/"
        control_path = "/data/mazurovev/controls/"
        data.append((row['File accession'], signal_path, row['Control'], control_path, row['norm_factor']))

# %%
from pathlib import Path
import shutil

# %%
callPeaks(data[0])
# Out:
# ENCFF457HGI
# done ENCFF457HGI
# 'INFO  @ Thu, 23 Apr 2020 14:38:27: Read and build bedGraph... \nINFO  @ Thu, 23 Apr 2020 14:38:46: Call peaks from bedGraph... \nINFO  @ Thu, 23 Apr 2020 14:38:47: Write peaks... \nINFO  @ Thu, 23 Apr 2020 14:38:47: Done \n'

# %%
data
# Out:
# [('ENCFF457HGI',
#   '/data/mazurovev/H3K27me3/UBERON:0002107/',
#   'ENCFF964MSO',
#   '/data/mazurovev/controls/',
#   0.761293),
#  ('ENCFF552NGA',
#   '/data/mazurovev/H3K27me3/UBERON:0002084/',
#   'ENCFF676AXV',
#   '/data/mazurovev/controls/',
#   0.4760474),
#  ('ENCFF237BOS',
#   '/data/mazurovev/H3K27me3/UBERON:0000948/',
#   'ENCFF589TFO',
#   '/data/mazurovev/controls/',
#   1.16537),
#  ('ENCFF156BTT',
#   '/data/mazurovev/H3K27me3/UBERON:0001515/',
#   'ENCFF924RQL',
#   '/data/mazurovev/controls/',
#   0.4023739),
#  ('ENCFF786XOM',
#   '/data/mazurovev/H3K27me3/UBERON:0001515/',
#   'ENCFF924RQL',
#   '/data/mazurovev/controls/',
#   0.4387103),
#  ('ENCFF785SBQ',
#   '/data/mazurovev/H3K27me3/EFO:0001187/',
#   'ENCFF255TUT',
#   '/data/mazurovev/controls/',
#   0.1663351),
#  ('ENCFF247LXA',
#   '/data/mazurovev/H3K27me3/EFO:0001187/',
#   'ENCFF255TUT',
#   '/data/mazurovev/controls/',
#   0.42088809999999993),
#  ('ENCFF122SGX',
#   '/data/mazurovev/H3K27me3/EFO:0005723/',
#   'ENCFF027OMV',
#   '/data/mazurovev/controls/',
#   0.4788635),
#  ('ENCFF943RTB',
#   '/data/mazurovev/H3K27me3/EFO:0005723/',
#   'ENCFF027OMV',
#   '/data/mazurovev/controls/',
#   0.4685009),
#  ('ENCFF186TYR',
#   '/data/mazurovev/H3K27me3/UBERON:0000992/',
#   'ENCFF791PRR',
#   '/data/mazurovev/controls/',
#   -1.0),
#  ('ENCFF144WWG',
#   '/data/mazurovev/H3K27me3/UBERON:0011907/',
#   'ENCFF634UHG',
#   '/data/mazurovev/controls/',
#   1.001636),
#  ('ENCFF234GEW',
#   '/data/mazurovev/H3K27me3/UBERON:0011907/',
#   'ENCFF634UHG',
#   '/data/mazurovev/controls/',
#   0.8358766),
#  ('ENCFF546HYL',
#   '/data/mazurovev/H3K27me3/UBERON:0002369/',
#   'ENCFF237BVB',
#   '/data/mazurovev/controls/',
#   0.8439027),
#  ('ENCFF860CKZ',
#   '/data/mazurovev/H3K27me3/CL:1001606/',
#   'ENCFF270SFZ',
#   '/data/mazurovev/controls/',
#   1.389024),
#  ('ENCFF108CVW',
#   '/data/mazurovev/H3K27me3/CL:1001606/',
#   'ENCFF270SFZ',
#   '/data/mazurovev/controls/',
#   1.5014809999999998),
#  ('ENCFF015OVW',
#   '/data/mazurovev/H3K27me3/CL:0002327/',
#   'ENCFF801RTD',
#   '/data/mazurovev/controls/',
#   0.3841786),
#  ('ENCFF843LLA',
#   '/data/mazurovev/H3K27me3/CL:0002327/',
#   'ENCFF801RTD',
#   '/data/mazurovev/controls/',
#   0.24923939999999997),
#  ('ENCFF228ZGV',
#   '/data/mazurovev/H3K27me3/UBERON:0002084/',
#   'ENCFF623DTG',
#   '/data/mazurovev/controls/',
#   0.7299188),
#  ('ENCFF208KVX',
#   '/data/mazurovev/H3K27me3/CL:0000182/',
#   'ENCFF248XON',
#   '/data/mazurovev/controls/',
#   0.6577142),
#  ('ENCFF523TBZ',
#   '/data/mazurovev/H3K27me3/CL:0000182/',
#   'ENCFF248XON',
#   '/data/mazurovev/controls/',
#   1.094364),
#  ('ENCFF193OFZ',
#   '/data/mazurovev/H3K27me3/CL:0000842/',
#   'ENCFF738UVB',
#   '/data/mazurovev/controls/',
#   0.7252854999999999),
#  ('ENCFF294WAV',
#   '/data/mazurovev/H3K27me3/CL:0000842/',
#   'ENCFF738UVB',
#   '/data/mazurovev/controls/',
#   0.44228370000000006),
#  ('ENCFF943RGA',
#   '/data/mazurovev/H3K27me3/UBERON:0001150/',
#   'ENCFF228XSQ',
#   '/data/mazurovev/controls/',
#   1.022297),
#  ('ENCFF399QGQ',
#   '/data/mazurovev/H3K27me3/CL:0000103/',
#   'ENCFF956GLJ',
#   '/data/mazurovev/controls/',
#   0.4174960999999999),
#  ('ENCFF122QYC',
#   '/data/mazurovev/H3K27me3/CL:0000103/',
#   'ENCFF956GLJ',
#   '/data/mazurovev/controls/',
#   0.5805701),
#  ('ENCFF337ODD',
#   '/data/mazurovev/H3K27me3/UBERON:0001211/',
#   'ENCFF110BDU',
#   '/data/mazurovev/controls/',
#   0.8110515),
#  ('ENCFF131KLD',
#   '/data/mazurovev/H3K27me3/UBERON:0004648/',
#   'ENCFF255WXC',
#   '/data/mazurovev/controls/',
#   0.4564688),
#  ('ENCFF796DDM',
#   '/data/mazurovev/H3K27me3/EFO:0002784/',
#   'ENCFF094HMB',
#   '/data/mazurovev/controls/',
#   0.8409698),
#  ('ENCFF927XRX',
#   '/data/mazurovev/H3K27me3/EFO:0002784/',
#   'ENCFF094HMB',
#   '/data/mazurovev/controls/',
#   0.6264198000000001),
#  ('ENCFF607WIJ',
#   '/data/mazurovev/H3K27me3/UBERON:0001159/',
#   'ENCFF999JOG',
#   '/data/mazurovev/controls/',
#   0.2733846),
#  ('ENCFF411QLO',
#   '/data/mazurovev/H3K27me3/UBERON:0001496/',
#   'ENCFF893ZJC',
#   '/data/mazurovev/controls/',
#   0.7870301),
#  ('ENCFF252XIN',
#   '/data/mazurovev/H3K27me3/CL:1001606/',
#   'ENCFF444OBR',
#   '/data/mazurovev/controls/',
#   1.243514),
#  ('ENCFF079MUK',
#   '/data/mazurovev/H3K27me3/CL:1001606/',
#   'ENCFF444OBR',
#   '/data/mazurovev/controls/',
#   1.366901),
#  ('ENCFF442ZRV',
#   '/data/mazurovev/H3K27me3/CL:0000127/',
#   'ENCFF639TYV',
#   '/data/mazurovev/controls/',
#   0.1781213),
#  ('ENCFF757AUJ',
#   '/data/mazurovev/H3K27me3/CL:0000127/',
#   'ENCFF639TYV',
#   '/data/mazurovev/controls/',
#   0.338854),
#  ('ENCFF020YIZ',
#   '/data/mazurovev/H3K27me3/CL:1001606/',
#   'ENCFF178GZR',
#   '/data/mazurovev/controls/',
#   1.529778),
#  ('ENCFF770OXM',
#   '/data/mazurovev/H3K27me3/CL:1001606/',
#   'ENCFF178GZR',
#   '/data/mazurovev/controls/',
#   1.4591120000000002),
#  ('ENCFF048FDD',
#   '/data/mazurovev/H3K27me3/UBERON:0002048/',
#   'ENCFF894ZBD',
#   '/data/mazurovev/controls/',
#   1.41337),
#  ('ENCFF129QUW',
#   '/data/mazurovev/H3K27me3/UBERON:0002240/',
#   'ENCFF879WYG',
#   '/data/mazurovev/controls/',
#   0.7060946),
#  ('ENCFF201WBT',
#   '/data/mazurovev/H3K27me3/UBERON:0002046/',
#   'ENCFF464KVS',
#   '/data/mazurovev/controls/',
#   0.7573099),
#  ('ENCFF249BFZ',
#   '/data/mazurovev/H3K27me3/UBERON:0002046/',
#   'ENCFF464KVS',
#   '/data/mazurovev/controls/',
#   1.117332),
#  ('ENCFF048HZR',
#   '/data/mazurovev/H3K27me3/UBERON:0001150/',
#   'ENCFF644ZVV',
#   '/data/mazurovev/controls/',
#   0.6822184),
#  ('ENCFF650KVU',
#   '/data/mazurovev/H3K27me3/UBERON:0011907/',
#   'ENCFF287TUT',
#   '/data/mazurovev/controls/',
#   0.5857286),
#  ('ENCFF585KVQ',
#   '/data/mazurovev/H3K27me3/UBERON:0002048/',
#   'ENCFF562SIS',
#   '/data/mazurovev/controls/',
#   0.6356130999999999),
#  ('ENCFF728OZT',
#   '/data/mazurovev/H3K27me3/UBERON:0002048/',
#   'ENCFF555QPV',
#   '/data/mazurovev/controls/',
#   0.34328159999999996),
#  ('ENCFF582NZD',
#   '/data/mazurovev/H3K27me3/UBERON:0000945/',
#   'ENCFF904DBV',
#   '/data/mazurovev/controls/',
#   0.2650356),
#  ('ENCFF880JQE',
#   '/data/mazurovev/H3K27me3/UBERON:0001150/',
#   'ENCFF590RZJ',
#   '/data/mazurovev/controls/',
#   0.6490549),
#  ('ENCFF864QHJ',
#   '/data/mazurovev/H3K27me3/CL:0002372/',
#   'ENCFF408COK',
#   '/data/mazurovev/controls/',
#   0.3668172),
#  ('ENCFF287IGX',
#   '/data/mazurovev/H3K27me3/CL:0002372/',
#   'ENCFF408COK',
#   '/data/mazurovev/controls/',
#   0.9450738000000001),
#  ('ENCFF575FWP',
#   '/data/mazurovev/H3K27me3/CL:0002518/',
#   'ENCFF115YWW',
#   '/data/mazurovev/controls/',
#   0.5737554),
#  ('ENCFF658MNZ',
#   '/data/mazurovev/H3K27me3/CL:0002518/',
#   'ENCFF115YWW',
#   '/data/mazurovev/controls/',
#   0.7631197),
#  ('ENCFF349LVZ',
#   '/data/mazurovev/H3K27me3/UBERON:0004648/',
#   'ENCFF144FKQ',
#   '/data/mazurovev/controls/',
#   0.8523233),
#  ('ENCFF500NQH',
#   '/data/mazurovev/H3K27me3/UBERON:0000945/',
#   'ENCFF386HHN',
#   '/data/mazurovev/controls/',
#   1.317884),
#  ('ENCFF880MZS',
#   '/data/mazurovev/H3K27me3/UBERON:0001323/',
#   'ENCFF782HSW',
#   '/data/mazurovev/controls/',
#   1.089528),
#  ('ENCFF114URN',
#   '/data/mazurovev/H3K27me3/UBERON:0008367/',
#   'ENCFF636AYA',
#   '/data/mazurovev/controls/',
#   1.833651),
#  ('ENCFF732UZB',
#   '/data/mazurovev/H3K27me3/UBERON:0002369/',
#   'ENCFF962WPS',
#   '/data/mazurovev/controls/',
#   0.38225),
#  ('ENCFF708NMK',
#   '/data/mazurovev/H3K27me3/UBERON:0002106/',
#   'ENCFF969DRM',
#   '/data/mazurovev/controls/',
#   0.49290200000000006),
#  ('ENCFF633HJH',
#   '/data/mazurovev/H3K27me3/UBERON:0011907/',
#   'ENCFF736RVR',
#   '/data/mazurovev/controls/',
#   1.115761),
#  ('ENCFF462BRB',
#   '/data/mazurovev/H3K27me3/CL:0000515/',
#   'ENCFF298NLV',
#   '/data/mazurovev/controls/',
#   1.533635),
#  ('ENCFF232HUV',
#   '/data/mazurovev/H3K27me3/CL:0000515/',
#   'ENCFF298NLV',
#   '/data/mazurovev/controls/',
#   0.9443546),
#  ('ENCFF190OWE',
#   '/data/mazurovev/H3K27me3/EFO:0002067/',
#   'ENCFF829HZY',
#   '/data/mazurovev/controls/',
#   0.45069209999999993),
#  ('ENCFF692KQZ',
#   '/data/mazurovev/H3K27me3/EFO:0002067/',
#   'ENCFF829HZY',
#   '/data/mazurovev/controls/',
#   0.3113598),
#  ('ENCFF673UOT',
#   '/data/mazurovev/H3K27me3/UBERON:0008952/',
#   'ENCFF981WUC',
#   '/data/mazurovev/controls/',
#   0.9402872999999999),
#  ('ENCFF083APJ',
#   '/data/mazurovev/H3K27me3/CL:0000746/',
#   'ENCFF120GPO',
#   '/data/mazurovev/controls/',
#   1.0907280000000001),
#  ('ENCFF407XPY',
#   '/data/mazurovev/H3K27me3/CL:0000746/',
#   'ENCFF120GPO',
#   '/data/mazurovev/controls/',
#   1.028216),
#  ('ENCFF124DET',
#   '/data/mazurovev/H3K27me3/UBERON:0001159/',
#   'ENCFF718BTS',
#   '/data/mazurovev/controls/',
#   0.6846053000000001),
#  ('ENCFF066QNC',
#   '/data/mazurovev/H3K27me3/UBERON:0001157/',
#   'ENCFF509UCY',
#   '/data/mazurovev/controls/',
#   0.5900404),
#  ('ENCFF310SBN',
#   '/data/mazurovev/H3K27me3/EFO:0003042/',
#   'ENCFF393RKZ',
#   '/data/mazurovev/controls/',
#   0.5242826),
#  ('ENCFF083QQZ',
#   '/data/mazurovev/H3K27me3/EFO:0003042/',
#   'ENCFF393RKZ',
#   '/data/mazurovev/controls/',
#   0.37017540000000004),
#  ('ENCFF030HAG',
#   '/data/mazurovev/H3K27me3/EFO:0001187/',
#   'ENCFF887ZEB',
#   '/data/mazurovev/controls/',
#   0.49192749999999996),
#  ('ENCFF394DQA',
#   '/data/mazurovev/H3K27me3/EFO:0001187/',
#   'ENCFF887ZEB',
#   '/data/mazurovev/controls/',
#   0.36553109999999994),
#  ('ENCFF421HFM',
#   '/data/mazurovev/H3K27me3/EFO:0005904/',
#   'ENCFF043XTH',
#   '/data/mazurovev/controls/',
#   0.8442357),
#  ('ENCFF250WQM',
#   '/data/mazurovev/H3K27me3/EFO:0005904/',
#   'ENCFF043XTH',
#   '/data/mazurovev/controls/',
#   0.3669206),
#  ('ENCFF862WYK',
#   '/data/mazurovev/H3K27me3/EFO:0007950/',
#   'ENCFF754UFV',
#   '/data/mazurovev/controls/',
#   0.1559884),
#  ('ENCFF371CJE',
#   '/data/mazurovev/H3K27me3/EFO:0007950/',
#   'ENCFF754UFV',
#   '/data/mazurovev/controls/',
#   0.2085539),
#  ('ENCFF825OWT',
#   '/data/mazurovev/H3K27me3/EFO:0001196/',
#   'ENCFF841PLU',
#   '/data/mazurovev/controls/',
#   0.8793098),
#  ('ENCFF868WTE',
#   '/data/mazurovev/H3K27me3/EFO:0001196/',
#   'ENCFF841PLU',
#   '/data/mazurovev/controls/',
#   1.4093870000000002),
#  ('ENCFF596SHE',
#   '/data/mazurovev/H3K27me3/EFO:0003042/',
#   'ENCFF236MNB',
#   '/data/mazurovev/controls/',
#   0.7492808000000001),
#  ('ENCFF830PVE',
#   '/data/mazurovev/H3K27me3/EFO:0003042/',
#   'ENCFF236MNB',
#   '/data/mazurovev/controls/',
#   0.5540645000000001),
#  ('ENCFF538OSP',
#   '/data/mazurovev/H3K27me3/UBERON:0000995/',
#   'ENCFF851BYG',
#   '/data/mazurovev/controls/',
#   1.267707),
#  ('ENCFF748KOZ',
#   '/data/mazurovev/H3K27me3/EFO:0003042/',
#   'ENCFF572GEP',
#   '/data/mazurovev/controls/',
#   1.126117),
#  ('ENCFF382GPJ',
#   '/data/mazurovev/H3K27me3/EFO:0003042/',
#   'ENCFF572GEP',
#   '/data/mazurovev/controls/',
#   0.6593793000000001),
#  ('ENCFF558UBX',
#   '/data/mazurovev/H3K27me3/UBERON:0002106/',
#   'ENCFF259EKT',
#   '/data/mazurovev/controls/',
#   2.120151),
#  ('ENCFF720LVW',
#   '/data/mazurovev/H3K27me3/UBERON:0001211/',
#   'ENCFF591VCF',
#   '/data/mazurovev/controls/',
#   1.20487),
#  ('ENCFF192EMA',
#   '/data/mazurovev/H3K27me3/UBERON:0000945/',
#   'ENCFF966QLG',
#   '/data/mazurovev/controls/',
#   0.2119364),
#  ('ENCFF189FFP',
#   '/data/mazurovev/H3K27me3/UBERON:0000945/',
#   'ENCFF419ELL',
#   '/data/mazurovev/controls/',
#   0.5889854999999999),
#  ('ENCFF404YFJ',
#   '/data/mazurovev/H3K27me3/UBERON:0002084/',
#   'ENCFF639VKM',
#   '/data/mazurovev/controls/',
#   0.3856112),
#  ('ENCFF207UDF',
#   '/data/mazurovev/H3K27me3/CL:0000746/',
#   'ENCFF504HBF',
#   '/data/mazurovev/controls/',
#   0.6270346),
#  ('ENCFF231YIP',
#   '/data/mazurovev/H3K27me3/CL:0000746/',
#   'ENCFF504HBF',
#   '/data/mazurovev/controls/',
#   0.6994156),
#  ('ENCFF327WQJ',
#   '/data/mazurovev/H3K27me3/CL:0000192/',
#   'ENCFF302IIT',
#   '/data/mazurovev/controls/',
#   0.9454577),
#  ('ENCFF509JMC',
#   '/data/mazurovev/H3K27me3/CL:0000192/',
#   'ENCFF302IIT',
#   '/data/mazurovev/controls/',
#   1.2637639999999999),
#  ('ENCFF951AJL',
#   '/data/mazurovev/H3K27me3/NTR:0000711/',
#   'ENCFF175BOB',
#   '/data/mazurovev/controls/',
#   0.6656618000000001),
#  ('ENCFF219YIY',
#   '/data/mazurovev/H3K27me3/NTR:0000711/',
#   'ENCFF175BOB',
#   '/data/mazurovev/controls/',
#   0.5840823),
#  ('ENCFF915XIL',
#   '/data/mazurovev/H3K27me3/EFO:0002067/',
#   'ENCFF355SGP',
#   '/data/mazurovev/controls/',
#   0.2175595),
#  ('ENCFF330YFF',
#   '/data/mazurovev/H3K27me3/EFO:0002067/',
#   'ENCFF355SGP',
#   '/data/mazurovev/controls/',
#   0.403469),
#  ('ENCFF813CKH',
#   '/data/mazurovev/H3K27me3/EFO:0005719/',
#   'ENCFF056BZA',
#   '/data/mazurovev/controls/',
#   1.398993),
#  ('ENCFF960YXZ',
#   '/data/mazurovev/H3K27me3/EFO:0005719/',
#   'ENCFF056BZA',
#   '/data/mazurovev/controls/',
#   1.4901659999999999),
#  ('ENCFF520NCF',
#   '/data/mazurovev/H3K27me3/CL:0002327/',
#   'ENCFF163IHR',
#   '/data/mazurovev/controls/',
#   0.3776231),
#  ('ENCFF798ITI',
#   '/data/mazurovev/H3K27me3/UBERON:0000995/',
#   'ENCFF326UUS',
#   '/data/mazurovev/controls/',
#   0.9073708),
#  ('ENCFF347INE',
#   '/data/mazurovev/H3K27me3/EFO:0002074/',
#   'ENCFF607ZQL',
#   '/data/mazurovev/controls/',
#   0.6693646),
#  ('ENCFF127CPB',
#   '/data/mazurovev/H3K27me3/EFO:0002074/',
#   'ENCFF607ZQL',
#   '/data/mazurovev/controls/',
#   0.6745229),
#  ('ENCFF834MYP',
#   '/data/mazurovev/H3K27me3/CL:0002553/',
#   'ENCFF681UKF',
#   '/data/mazurovev/controls/',
#   0.6331863),
#  ('ENCFF535LEC',
#   '/data/mazurovev/H3K27me3/CL:0002553/',
#   'ENCFF681UKF',
#   '/data/mazurovev/controls/',
#   0.5474273000000001),
#  ('ENCFF425HDW',
#   '/data/mazurovev/H3K27me3/CL:0002328/',
#   'ENCFF682GMA',
#   '/data/mazurovev/controls/',
#   0.6348666000000001),
#  ('ENCFF518FAE',
#   '/data/mazurovev/H3K27me3/CL:0002328/',
#   'ENCFF682GMA',
#   '/data/mazurovev/controls/',
#   0.7422186),
#  ('ENCFF533REZ',
#   '/data/mazurovev/H3K27me3/UBERON:0000473/',
#   'ENCFF054TED',
#   '/data/mazurovev/controls/',
#   1.1382),
#  ('ENCFF318IMH',
#   '/data/mazurovev/H3K27me3/CL:0000062/',
#   'ENCFF535QXZ',
#   '/data/mazurovev/controls/',
#   0.1739588),
#  ('ENCFF798RLD',
#   '/data/mazurovev/H3K27me3/CL:0000062/',
#   'ENCFF535QXZ',
#   '/data/mazurovev/controls/',
#   0.5675741),
#  ('ENCFF175YYN',
#   '/data/mazurovev/H3K27me3/EFO:0002784/',
#   'ENCFF684NLR',
#   '/data/mazurovev/controls/',
#   0.8666805000000001),
#  ('ENCFF231DJN',
#   '/data/mazurovev/H3K27me3/EFO:0002784/',
#   'ENCFF684NLR',
#   '/data/mazurovev/controls/',
#   1.227264),
#  ('ENCFF201JXX',
#   '/data/mazurovev/H3K27me3/UBERON:0001323/',
#   'ENCFF925HTZ',
#   '/data/mazurovev/controls/',
#   0.7536111),
#  ('ENCFF316LIQ',
#   '/data/mazurovev/H3K27me3/UBERON:0008952/',
#   'ENCFF163YFX',
#   '/data/mazurovev/controls/',
#   1.367473),
#  ('ENCFF403ZNV',
#   '/data/mazurovev/H3K27me3/UBERON:0001157/',
#   'ENCFF742DCE',
#   '/data/mazurovev/controls/',
#   1.134496),
#  ('ENCFF924JKS',
#   '/data/mazurovev/H3K27me3/UBERON:0002046/',
#   'ENCFF079PQP',
#   '/data/mazurovev/controls/',
#   0.5141673),
#  ('ENCFF202EUA',
#   '/data/mazurovev/H3K27me3/UBERON:0002106/',
#   'ENCFF608SQR',
#   '/data/mazurovev/controls/',
#   0.7545149),
#  ('ENCFF123VMN',
#   '/data/mazurovev/H3K27me3/UBERON:0006631/',
#   'ENCFF524KQP',
#   '/data/mazurovev/controls/',
#   0.9665134),
#  ('ENCFF245SNK',
#   '/data/mazurovev/H3K27me3/UBERON:0006920/',
#   'ENCFF305KDB',
#   '/data/mazurovev/controls/',
#   1.120637),
#  ('ENCFF741NYO',
#   '/data/mazurovev/H3K27me3/UBERON:0001496/',
#   'ENCFF299AOC',
#   '/data/mazurovev/controls/',
#   0.7162651),
#  ('ENCFF484XQD',
#   '/data/mazurovev/H3K27me3/UBERON:0001157/',
#   'ENCFF665FWN',
#   '/data/mazurovev/controls/',
#   0.8630815999999999)]

# %%
for d in data:
    model = Path('/home/mazurovev/scripts/' + d[0] + "_model.r")
    peaks = Path('/home/mazurovev/scripts/' + d[0] + "_peaks.narrowPeak")
    xls_peaks = Path('/home/mazurovev/scripts/' + d[0] + "_peaks.xls")
    summits = Path('/home/mazurovev/scripts/' + d[0] + "_summits.bed")
    
    dst_model = Path(d[1] + d[0] + "_model.r")
    dst_peaks = Path(d[1] + d[0] + "_peaks.narrowPeak")
    dst_xls_peaks = Path(d[1] + d[0] + "_peaks.xls")
    dst_summits = Path(d[1] + d[0] + "_summits.bed")
    
    shutil.move(model, dst_model)
    shutil.move(peaks, dst_peaks)
    shutil.move(xls_peaks, dst_xls_peaks)
    shutil.move(summits, dst_summits)

# %%
pool = Pool(processes=10)
outputs = pool.map(callPeaks, data)

pool.close()
pool.join()
# Out:
# ENCFF247LXA
# ENCFF156BTT
# ENCFF186TYR
# ENCFF546HYL
# ENCFF015OVW
# ENCFF208KVX
# ENCFF294WAV
# ENCFF122QYC
# ENCFF796DDM
# ENCFF411QLO
# done ENCFF796DDM
# ENCFF927XRX
# done ENCFF015OVW
# ENCFF843LLA
# done ENCFF927XRX
# ENCFF607WIJ
# done ENCFF247LXA
# ENCFF122SGX
# done ENCFF843LLA
# ENCFF228ZGV
# done ENCFF546HYL
# ENCFF860CKZ
# done ENCFF186TYR
# ENCFF144WWG
# done ENCFF294WAV
# ENCFF943RGA
# done ENCFF228ZGV
# ENCFF442ZRV
# done ENCFF156BTT
# ENCFF786XOM
# done ENCFF411QLO
# ENCFF252XIN
# done ENCFF122QYC
# ENCFF337ODD
# done ENCFF442ZRV
# ENCFF757AUJ
# done ENCFF607WIJ
# ENCFF770OXM
# done ENCFF208KVX
# ENCFF523TBZ
# done ENCFF122SGX
# ENCFF943RTB
# done ENCFF144WWG
# ENCFF234GEW
# done ENCFF943RGA
# ENCFF399QGQ
# done ENCFF757AUJ
# ENCFF020YIZ
# done ENCFF786XOM
# ENCFF785SBQ
# done ENCFF337ODD
# ENCFF131KLD
# done ENCFF860CKZ
# ENCFF108CVW
# done ENCFF943RTB
# ENCFF201WBT
# done ENCFF785SBQ
# ENCFF650KVU
# done ENCFF234GEW
# ENCFF582NZD
# done ENCFF399QGQ
# ENCFF287IGX
# done ENCFF252XIN
# ENCFF079MUK
# done ENCFF582NZD
# ENCFF880JQE
# done ENCFF201WBT
# ENCFF249BFZ
# done ENCFF650KVU
# ENCFF585KVQ
# done ENCFF523TBZ
# ENCFF193OFZ
# done ENCFF287IGX
# ENCFF575FWP
# done ENCFF770OXM
# ENCFF048FDD
# done ENCFF575FWP
# ENCFF658MNZ
# done ENCFF020YIZ
# ENCFF349LVZ
# done ENCFF048FDD
# ENCFF129QUW
# done ENCFF585KVQ
# ENCFF728OZT
# done ENCFF658MNZ
# ENCFF114URN
# done ENCFF249BFZ
# ENCFF048HZR
# done ENCFF193OFZ
# ENCFF633HJH
# done ENCFF728OZT
# ENCFF190OWE
# done ENCFF129QUW
# ENCFF083APJ
# done ENCFF108CVW
# ENCFF066QNC
# done ENCFF131KLD
# ENCFF030HAG
# done ENCFF190OWE
# ENCFF692KQZ
# done ENCFF030HAG
# ENCFF394DQA
# done ENCFF692KQZ
# ENCFF673UOT
# done ENCFF394DQA
# ENCFF421HFM
# done ENCFF349LVZ
# ENCFF500NQH
# done ENCFF048HZR
# ENCFF250WQM
# done ENCFF079MUK
# ENCFF825OWT
# done ENCFF114URN
# ENCFF732UZB
# done ENCFF880JQE
# ENCFF864QHJ
# done ENCFF421HFM
# ENCFF830PVE
# done ENCFF083APJ
# ENCFF407XPY
# done ENCFF250WQM
# ENCFF862WYK
# done ENCFF825OWT
# ENCFF868WTE
# done ENCFF633HJH
# ENCFF462BRB
# done ENCFF830PVE
# ENCFF538OSP
# done ENCFF462BRB
# ENCFF232HUV
# done ENCFF232HUV
# ENCFF382GPJ
# done ENCFF868WTE
# ENCFF596SHE
# done ENCFF732UZB
# ENCFF708NMK
# done ENCFF382GPJ
# ENCFF558UBX
# done ENCFF864QHJ
# ENCFF192EMA
# done ENCFF596SHE
# ENCFF207UDF
# done ENCFF558UBX
# ENCFF720LVW
# done ENCFF708NMK
# ENCFF509JMC
# done ENCFF207UDF
# ENCFF231YIP
# done ENCFF407XPY
# ENCFF124DET
# done ENCFF673UOT
# ENCFF915XIL
# done ENCFF500NQH
# ENCFF880MZS
# done ENCFF066QNC
# ENCFF310SBN
# done ENCFF124DET
# ENCFF960YXZ
# done ENCFF231YIP
# ENCFF327WQJ
# done ENCFF310SBN
# ENCFF083QQZ
# done ENCFF192EMA
# ENCFF189FFP
# done ENCFF083QQZ
# ENCFF347INE
# done ENCFF915XIL
# ENCFF330YFF
# done ENCFF509JMC
# ENCFF951AJL
# done ENCFF538OSP
# ENCFF748KOZ
# done ENCFF748KOZ
# ENCFF535LEC
# done ENCFF862WYK
# ENCFF371CJE
# done ENCFF327WQJ
# ENCFF533REZ
# done ENCFF330YFF
# ENCFF813CKH
# done ENCFF535LEC
# ENCFF425HDW
# done ENCFF960YXZ
# ENCFF520NCF
# done ENCFF880MZS
# ENCFF175YYN
# done ENCFF175YYN
# ENCFF231DJN
# done ENCFF425HDW
# ENCFF518FAE
# done ENCFF520NCF
# ENCFF798ITI
# done ENCFF231DJN
# ENCFF201JXX
# done ENCFF518FAE
# ENCFF316LIQ
# done ENCFF347INE
# ENCFF127CPB
# done ENCFF813CKH
# ENCFF202EUA
# done ENCFF951AJL
# ENCFF219YIY
# done ENCFF720LVW
# ENCFF741NYO
# done ENCFF189FFP
# ENCFF404YFJ
# done ENCFF533REZ
# done ENCFF201JXX
# done ENCFF316LIQ
# ENCFF403ZNV
# done ENCFF202EUA
# ENCFF123VMN
# done ENCFF127CPB
# ENCFF834MYP
# done ENCFF741NYO
# ENCFF484XQD
# done ENCFF371CJE
# done ENCFF834MYP
# done ENCFF219YIY
# done ENCFF798ITI
# done ENCFF403ZNV
# ENCFF924JKS
# done ENCFF484XQD
# done ENCFF123VMN
# ENCFF245SNK
# done ENCFF404YFJ
# done ENCFF924JKS
# done ENCFF245SNK
# ---------------------------------------------------------------------------
# RemoteTraceback                           Traceback (most recent call last)
# RemoteTraceback:
# """
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/usr/lib/python3.6/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-13-04a900ea8e8e>", line 25, in callPeaks
#     os.mkdir(tmp_dir)
# FileExistsError: [Errno 17] File exists: '/data/mazurovev/tmp_peaks/tmp_call_peaks_for_ENCFF457HGI'
# """
#
# The above exception was the direct cause of the following exception:
#
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-16-d90cd6ce64eb> in <module>()
#       1 pool = Pool(processes=10)
# ----> 2 outputs = pool.map(callPeaks, data)
#       3
#       4 pool.close()
#       5 pool.join()
#
# /usr/lib/python3.6/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# /usr/lib/python3.6/multiprocessing/pool.py in get(self, timeout)
#     642             return self._value
#     643         else:
# --> 644             raise self._value
#     645
#     646     def _set(self, i, obj):
#
# FileExistsError: [Errno 17] File exists: '/data/mazurovev/tmp_peaks/tmp_call_peaks_for_ENCFF457HGI'

# %%
#========================

# %%
#callpeak -t ENCFF318IMH.bed -c /data/mazurovev/controls/ENCFF535QXZ.bed -f BED --broad -g 2.9e9 -q 0.05 -n macs2_original --broad-cutoff 0.05 --ratio 0.1739588
