# %%
import xml.etree.ElementTree as ET
import random

# %%
class PoAPowersGenerator:
    
    LINE_LENGTH = 60
    
    def __init__(self, xml):
        tree = ET.parse(xml)
        self.root = tree.getroot()
        
        self.current_line = 0
        self.current_end_of_prev_token = 0
    
    def find_all_frames(self, frame=None, offset='', markup=[]):
        #if frame.attrib['name'] != 'Блоки':  # Не ясно почему у фрейма 'Блоки' нет limitations
        #    print(offset + frame.attrib['name'] + 
        #              ", limitations: minOccurs - " + frame.attrib['minOccurs'] + 
        #              ", maxOccurs - " + frame.attrib['maxOccurs'])
        #else:
        #    print(offset + frame.attrib['name'])

        # Тут для каждого фрейма надо понять сколько их будет и делать цикл
        
        if not frame:
            frame = self.root
        
        frame_count = get_tag_count(frame)
        print(str(frame_count) + " блоков " + frame.attrib['name'])
        for i in range(frame_count):
            nodes = []
            frame_markup = {frame.attrib['name']: nodes}
            markup.append(frame_markup)

            for sub_frame in frame.find('children').findall('frame'):
                find_all_frames(sub_frame, offset + "\t", nodes)

            find_quotes(frame, offset, nodes)
            find_entities(frame, offset, nodes)
            find_categories(frame, offset, nodes)
            
        return markup
        
    # TODO: по данным получить распределения кол-ва фреймов и генерить число из них
    # сейчас можно использовать равномерное распределение, но возможно лучше использвать Пуассона

    #В принципе, для наших целей не важно количество, но вообще все это можно было бы использовать для 
    #аугментации прав
    def get_tag_count(self, frame):
        if frame.attrib['name'] == 'Полномочия':
            max_occurs = frame.attrib['maxOccurs']
            return random.randint(int(frame.attrib['minOccurs']), int(max_occurs) if max_occurs != 'unbounded' else 2)
        if frame.attrib['name'] == 'Действие':
            max_occurs = frame.attrib['maxOccurs']
            return random.randint(int(frame.attrib['minOccurs']), int(max_occurs) if max_occurs != 'unbounded' else 2)

        return 1
    
    def find_quotes(self, elem, offset, nodes):
        for quote in elem.find('children').findall('quote'):
            for i in range(get_tag_count(quote)):
                quote_markup = {"value": quote.attrib['name'], 
                                "entity_id": 0, 
                                "text_pos": get_token_coords(quote, current_line, current_end_of_prev_token)}
                nodes.append({quote.attrib['name']: quote_markup})

            #print(offset + "\t" + "quote: " + quote.attrib['name'] + 
            #      ", limitations: minOccurs - " + quote.attrib['minOccurs'] + 
            #      ", maxOccurs - " + quote.attrib['maxOccurs'])

    def get_token_coords(self, tag):
        token_length = len(tag.attrib['name'])

        start_pos = [self.current_line, self.current_end_of_prev_token]

        possible_end_pos = current_end_of_prev_token + token_length
        if possible_end_pos > LINE_LENGTH:
            self.current_line = current_line + 1
            self.current_end_of_prev_token = possible_end_pos - LINE_LENGTH

        end_pos = [self.current_line, self.current_end_of_prev_token]

        return [start_pos, end_pos]
    
    def find_entities(self, elem, offset, nodes):
        for entity in elem.find('children').findall('entity'):
            for i in range(get_tag_count(entity)):
                entity_markup = {"value": "value", "entity_id": 0, "text_pos": [[], []]}
                nodes.append({entity.attrib['name']: entity_markup})

            #print(offset + "\t" + "entity: " + entity.attrib['name'] + 
            #      ", limitations: minOccurs - " + entity.attrib['minOccurs'] + 
            #      ", maxOccurs - " + entity.attrib['maxOccurs'])
            
    def find_categories(self, elem, offset, nodes):
        for category in elem.find('children').findall('category'):
            for i in range(get_tag_count(category)):
                nodes.append({category.attrib['name'] + "__category_list": "category"})

            #print(offset + "\t" + "category: " + category.attrib['name'] + 
            #      ", limitations: minOccurs - " + category.attrib['minOccurs'] + 
            #      ", maxOccurs - " + category.attrib['maxOccurs'])

# %%
generator = PoAPowersGenerator('/home/mazurovev/powers.xml')

# %%
markup = generator.find_all_frames()
# Out:
# 1 блоков Блоки
# 0 блоков Полномочия
# 1 блоков ОбщиеОграничения
# 1 блоков Территория
# 1 блоков ЗаИсключением
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-229-abd7175f7fa4> in <module>()
# ----> 1 markup = generator.find_all_frames()
#
# <ipython-input-227-a792d8e75663> in find_all_frames(self, frame, offset, markup)
#      31
#      32             for sub_frame in frame.find('children').findall('frame'):
# ---> 33                 find_all_frames(sub_frame, offset + "\t", nodes)
#      34
#      35             find_quotes(frame, offset, nodes)
#
# <ipython-input-218-7cc24877d625> in find_all_frames(frame, offset, markup)
#      20
#      21         for sub_frame in frame.find('children').findall('frame'):
# ---> 22             find_all_frames(sub_frame, offset + "\t", nodes)
#      23
#      24         find_quotes(frame, offset, nodes, current_line, current_end_of_prev_token)
#
# <ipython-input-218-7cc24877d625> in find_all_frames(frame, offset, markup)
#      20
#      21         for sub_frame in frame.find('children').findall('frame'):
# ---> 22             find_all_frames(sub_frame, offset + "\t", nodes)
#      23
#      24         find_quotes(frame, offset, nodes, current_line, current_end_of_prev_token)
#
# <ipython-input-218-7cc24877d625> in find_all_frames(frame, offset, markup)
#      23
#      24         find_quotes(frame, offset, nodes, current_line, current_end_of_prev_token)
# ---> 25         find_entities(frame, offset, nodes, current_line, current_end_of_prev_token)
#      26         find_categories(frame, offset, nodes)
#
# TypeError: find_entities() takes 3 positional arguments but 5 were given

# %%
all_markup
# Out:
# [{'Блоки': [{'ОбщиеОграничения': [{'Территория': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ЗаИсключениемПризнак__category_list': 'category'}]},
#        {'МестоЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'МестоКЕ': {'value': 'value', 'entity_id': 0, 'text_pos': [[], []]}}]},
#      {'Контрагент': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ЗаИсключениемПризнак__category_list': 'category'}]},
#        {'КонтрагентЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'КонтрагентКЕ': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'КонтрагентТип__category_list': 'category'}]},
#      {'КотрагентЦепочка': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ЗаИсключениемПризнак__category_list': 'category'}]},
#        {'Контрагент': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'ЗаИсключениемПризнак__category_list': 'category'}]},
#          {'КонтрагентЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'КонтрагентКЕ': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'КонтрагентТип__category_list': 'category'}]},
#        {'КонтрагентЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ДенежныеОграничения': [{'Цитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'Цифры': {'value': 'value', 'entity_id': 0, 'text_pos': [[], []]}}]},
#      {'ОграниченияСрокДоговора': [{'Цитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'СрокДоговора': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ПредваритСогласие': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}}]},
#    {'ОбщиеПолномочия': [{'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'ДействиеЦепочка': [{'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'ДействиеЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ОбъектДействий': [{'ОбъектЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ОбъектСчет': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипОбъекта__category_list': 'category'}]},
#      {'ОбъектДействийЦепочка': [{'ОбъектДействий': [{'ОбъектЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ОбъектСчет': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипОбъекта__category_list': 'category'}]},
#        {'ОбъектЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ИсключенияДействие': [{'ИсключенияДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключенияТипДействия__category_list': 'category'}]},
#      {'ИсключенияДействиеЦепочка': [{'ИсключенияДействие': [{'ИсключенияДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключенияТипДействия__category_list': 'category'}]},
#        {'ИсключенияДействиеЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ИсключенияОбъектДействий': [{'ИсключениеОбъектЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключениеОбъектСчет': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключениеТипОбъекта__category_list': 'category'}]},
#      {'ИсключенияОбъектДействийЦепочка': [{'ИсключенияОбъектДействий': [{'ИсключениеОбъектЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключениеОбъектСчет': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключениеТипОбъекта__category_list': 'category'}]},
#        {'ИсключениеОбъектЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ДействиеОбъектСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}},
#      {'ИсключенияДействиеСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}},
#      {'ИсключениеОбъектСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}}]}]},
#  {'Блоки': [{'Полномочия': [{'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'ДействиеЦепочка': [{'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'ДействиеЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ОбъектДействий': [{'ОбъектЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ОбъектСчет': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипОбъекта__category_list': 'category'}]},
#      {'ОбъектДействийЦепочка': [{'ОбъектДействий': [{'ОбъектЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ОбъектСчет': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипОбъекта__category_list': 'category'}]},
#        {'ОбъектЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ИсключенияДействие': [{'ИсключенияДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключенияТипДействия__category_list': 'category'}]},
#      {'ИсключенияДействиеЦепочка': [{'ИсключенияДействие': [{'ИсключенияДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключенияТипДействия__category_list': 'category'}]},
#        {'ИсключенияДействиеЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ИсключенияОбъектДействий': [{'ИсключениеОбъектЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключениеОбъектСчет': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключениеТипОбъекта__category_list': 'category'}]},
#      {'ИсключенияОбъектДействийЦепочка': [{'ИсключенияОбъектДействий': [{'ИсключениеОбъектЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключениеОбъектСчет': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключениеТипОбъекта__category_list': 'category'}]},
#        {'ИсключениеОбъектЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'Ограничения': [{'Территория': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'ЗаИсключениемПризнак__category_list': 'category'}]},
#          {'МестоЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'МестоКЕ': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}}]},
#        {'Контрагент': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'ЗаИсключениемПризнак__category_list': 'category'}]},
#          {'КонтрагентЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'КонтрагентКЕ': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'КонтрагентТип__category_list': 'category'}]},
#        {'КотрагентЦепочка': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'ЗаИсключениемПризнак__category_list': 'category'}]},
#          {'Контрагент': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#                'entity_id': 0,
#                'text_pos': [[], []]}},
#              {'ЗаИсключениемПризнак__category_list': 'category'}]},
#            {'КонтрагентЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'КонтрагентКЕ': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'КонтрагентТип__category_list': 'category'}]},
#          {'КонтрагентЦитатаОбщая': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}}]},
#        {'ДенежныеОграничения': [{'Цитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'Цифры': {'value': 'value', 'entity_id': 0, 'text_pos': [[], []]}}]},
#        {'ОграниченияСрокДоговора': [{'Цитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'СрокДоговора': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}}]},
#        {'ПредваритСогласие': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ДействиеОбъектСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}},
#      {'ИсключенияДействиеСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}},
#      {'ИсключениеОбъектСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}}]},
#    {'Полномочия': [{'ДействиеЦепочка': [{'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'ДействиеЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ОбъектДействий': [{'ОбъектЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ОбъектСчет': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипОбъекта__category_list': 'category'}]},
#      {'ОбъектДействийЦепочка': [{'ОбъектДействий': [{'ОбъектЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ОбъектСчет': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипОбъекта__category_list': 'category'}]},
#        {'ОбъектЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ИсключенияДействие': [{'ИсключенияДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключенияТипДействия__category_list': 'category'}]},
#      {'ИсключенияДействиеЦепочка': [{'ИсключенияДействие': [{'ИсключенияДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключенияТипДействия__category_list': 'category'}]},
#        {'ИсключенияДействиеЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ИсключенияОбъектДействий': [{'ИсключениеОбъектЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключениеОбъектСчет': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключениеТипОбъекта__category_list': 'category'}]},
#      {'ИсключенияОбъектДействийЦепочка': [{'ИсключенияОбъектДействий': [{'ИсключениеОбъектЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключениеОбъектСчет': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключениеТипОбъекта__category_list': 'category'}]},
#        {'ИсключениеОбъектЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'Ограничения': [{'Территория': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'ЗаИсключениемПризнак__category_list': 'category'}]},
#          {'МестоЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'МестоКЕ': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}}]},
#        {'Контрагент': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'ЗаИсключениемПризнак__category_list': 'category'}]},
#          {'КонтрагентЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'КонтрагентКЕ': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'КонтрагентТип__category_list': 'category'}]},
#        {'КотрагентЦепочка': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'ЗаИсключениемПризнак__category_list': 'category'}]},
#          {'Контрагент': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#                'entity_id': 0,
#                'text_pos': [[], []]}},
#              {'ЗаИсключениемПризнак__category_list': 'category'}]},
#            {'КонтрагентЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'КонтрагентКЕ': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'КонтрагентТип__category_list': 'category'}]},
#          {'КонтрагентЦитатаОбщая': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}}]},
#        {'ДенежныеОграничения': [{'Цитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'Цифры': {'value': 'value', 'entity_id': 0, 'text_pos': [[], []]}}]},
#        {'ОграниченияСрокДоговора': [{'Цитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'СрокДоговора': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}}]},
#        {'ПредваритСогласие': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ДействиеОбъектСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}},
#      {'ИсключенияДействиеСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}},
#      {'ИсключениеОбъектСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}}]},
#    {'ОбщиеОграничения': [{'Территория': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ЗаИсключениемПризнак__category_list': 'category'}]},
#        {'МестоЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'МестоКЕ': {'value': 'value', 'entity_id': 0, 'text_pos': [[], []]}}]},
#      {'Контрагент': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ЗаИсключениемПризнак__category_list': 'category'}]},
#        {'КонтрагентЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'КонтрагентКЕ': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'КонтрагентТип__category_list': 'category'}]},
#      {'КотрагентЦепочка': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ЗаИсключениемПризнак__category_list': 'category'}]},
#        {'Контрагент': [{'ЗаИсключением': [{'ЗаИсключениемЦитата': {'value': 'value',
#              'entity_id': 0,
#              'text_pos': [[], []]}},
#            {'ЗаИсключениемПризнак__category_list': 'category'}]},
#          {'КонтрагентЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'КонтрагентКЕ': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'КонтрагентТип__category_list': 'category'}]},
#        {'КонтрагентЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ДенежныеОграничения': [{'Цитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'Цифры': {'value': 'value', 'entity_id': 0, 'text_pos': [[], []]}}]},
#      {'ОграниченияСрокДоговора': [{'Цитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'СрокДоговора': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ПредваритСогласие': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}}]},
#    {'ОбщиеПолномочия': [{'Действие': [{'ДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипДействия__category_list': 'category'}]},
#      {'ДействиеЦепочка': [{'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'Действие': [{'ДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипДействия__category_list': 'category'}]},
#        {'ДействиеЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ОбъектДействий': [{'ОбъектЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ОбъектСчет': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ТипОбъекта__category_list': 'category'}]},
#      {'ОбъектДействийЦепочка': [{'ОбъектДействий': [{'ОбъектЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ОбъектСчет': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ТипОбъекта__category_list': 'category'}]},
#        {'ОбъектЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ИсключенияДействие': [{'ИсключенияДействиеЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключенияТипДействия__category_list': 'category'}]},
#      {'ИсключенияДействиеЦепочка': [{'ИсключенияДействие': [{'ИсключенияДействиеЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключенияТипДействия__category_list': 'category'}]},
#        {'ИсключенияДействиеЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ИсключенияОбъектДействий': [{'ИсключениеОбъектЦитата': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключениеОбъектСчет': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}},
#        {'ИсключениеТипОбъекта__category_list': 'category'}]},
#      {'ИсключенияОбъектДействийЦепочка': [{'ИсключенияОбъектДействий': [{'ИсключениеОбъектЦитата': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключениеОбъектСчет': {'value': 'value',
#            'entity_id': 0,
#            'text_pos': [[], []]}},
#          {'ИсключениеТипОбъекта__category_list': 'category'}]},
#        {'ИсключениеОбъектЦитатаОбщая': {'value': 'value',
#          'entity_id': 0,
#          'text_pos': [[], []]}}]},
#      {'ДействиеОбъектСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}},
#      {'ИсключенияДействиеСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}},
#      {'ИсключениеОбъектСвязка': {'value': 'value',
#        'entity_id': 0,
#        'text_pos': [[], []]}}]}]}]
