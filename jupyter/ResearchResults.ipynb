# %%
#Несовпадение ативатор/репрессор типа метки в наших результатах, 
#посмотреть в данных(у нас и фантом)как получается что мы считаем, что активаторная метка ведет себя как репрессорная

# %%
#Сколько в каждой колонке случаев?
#Есть ли перекосы в знаке FC?(попытка объяснить перекосы в результатах)
#Построить разные графики соотношений по меткам, кол-ву пиков, генов и прочему
#Почему мало значимых кейсов для репрессорных меток? и Почему меньше кейсов для wr er - перекос в данных? 
# такой отбор нкРНК?
#Можно объяснить несоответствие несколькими способами: 1)метки могут вести себя по разному(быть и такими и такими)
# 2)Они ведут себя как надо, но забиваются другими вещами
# 3)Статистический шум
# 4)Мы можем не находить настоящих кейсов, потому что эта рнк может ставить метку реально в очень малом количестве
#мест(бывает ли такое?)
# 5)Мы рассматриваем метки только в генах и рядом с ними, т.е. не рассматриваем энхансеры и прочее

# %%
#Как можно уточнять результаты?
#Проверить данные по меткам на согласованность
#Использовать другие механизмы, объясняющие изменение экспрессии кроме меток(!!!)(как часто вообще это метки?
#на сколько это динамично происходит?) например спонжи

# %%
#Поискать в наших данных на разных этапах известные случаи и места на геноме

# %%
#Использовать другой тест для согласования данных по корреляции и по нокдауну
#Как то включить в анализ поправки, что мол тут с какой-то вероятностью ошибка в результате, 
#потом мы его используем дальше еще с другой вероятностью ошибка. И так далее

# %%
#Внимательно изучить пики, использовать реплики, пересчитать максом с другой значимостью, прочекать нормализацию
#Как проверить пики?(кроме тех корреляций)
#Как оценить насколько точные пики нам нужны?
#Подумать как еще можно объянить корреляцию между меткой и экспрессией(!!!)?
#Подумать о другой метрике вместо корреляций

# %%
import pandas as pd

# %%
p_values = pd.read_csv("/home/mazurovev/all_marks/H3K27me3/our_fantom_genes_association_pvalues.tsv", sep="\t")

# %%
p_values
# Out:
#           lncRNAId     lncRNAName    pvalue     mm_pvalue  mp_pvalue  \
# 0  ENSG00000212978     AC016747.3  0.007815  3.855548e-07   1.000000
# 1  ENSG00000253161  RP11-150O12.1  0.117410  5.198128e-03   0.608304
# 2  ENSG00000234608   MAPKAPK5-AS1  0.003293  6.415097e-29   0.059207
# 3  ENSG00000256268  RP11-221N13.3  0.117410  2.451685e-04   1.000000
# 4  ENSG00000246430      LINC00968  0.425893  1.812014e-02   1.000000
# 5  ENSG00000233396  RP11-458D21.1  1.000000  4.726189e-05   0.340458
# 6  ENSG00000246273       SBF2-AS1  0.400835  1.800876e-02   0.395428
#
#       pm_pvalue     pp_pvalue
# 0  1.000000e+00  1.000000e+00
# 1  6.299648e-01  1.000000e+00
# 2  1.000000e+00  1.000000e+00
# 3  2.913750e-01  1.000000e+00
# 4  1.000000e+00  1.000000e+00
# 5  1.857873e-28  7.512393e-19
# 6  2.913750e-01  1.000000e+00

# %%
counts = pd.read_csv("/home/mazurovev/all_marks/H3K27me3/our_fantom_genes_association.tsv", sep="\t")

# %%
counts
# Out:
#            lncRNAId     lncRNAName   our  our_p  our_m  fantom  fantom_p  \
# 0   ENSG00000212978     AC016747.3  2847   1423   1542     956       405
# 1   ENSG00000260032      LINC00657    95     30     65    1192       532
# 2   ENSG00000223485   RP11-417E7.1    32     14     18    6640      3348
# 3   ENSG00000253161  RP11-150O12.1  1957    520   1465    1928       941
# 4   ENSG00000260565       ERVK13-1   363     98    268      18         1
# 5   ENSG00000225791      TRAM2-AS1   989    654    340       4         1
# 6   ENSG00000227053   RP11-395B7.4    63     31     32    3096      1313
# 7   ENSG00000225733       FGD5-AS1    66     33     33    1232       489
# 8   ENSG00000240875      LINC00886    28      6     22    1145       556
# 9   ENSG00000234456      MAGI2-AS3   204     60    144      74         9
# 10  ENSG00000234608   MAPKAPK5-AS1  4571   3331   1476    1920       780
# 11  ENSG00000256268  RP11-221N13.3  1683    500   1204     693       316
# ...

# %%
#Какие известные кРНК замешаны в установке метки H3K27me3?
#MEG3, LINC00702, LINC00968, LINC00511, SBF2-AS1,MAPKAPK5-AS1, PVT1, Xist, HOTAIR, ANRIL, KCNQ1OT1,
#NEAT1, NEAT2(MALAT1)
