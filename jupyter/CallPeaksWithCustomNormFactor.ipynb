# %%
import pandas as pd
import subprocess
import re
import os
import matplotlib.pyplot as plt
import shutil
from multiprocessing import Pool
from pathlib import Path
import shutil

# %%
#!!TODO: возможно надо делать меньше порог на p-value

# %%
d = pd.read_csv("../all_marks/ChiP-Seq_for_all_marks_all_replicas.tsv", sep='\t', index_col=False)

# %%
#macs2 filterdup -i CTCF_ChIP_200K.bed.gz --keep-dup=1 -o CTCF_ChIP_200K_filterdup.bed
#macs2 filterdup -i CTCF_ChIP_200K_control.bed.gz --keep-dup=1 -o CTCF_ChIP_200K_control_filterdup.bed
#macs2 predictd -i CTCF_ChIP_200K_filterdup.bed -g hs -m 5 50
#macs2 pileup -i CTCF_ChIP_200K_filterdup.bed -o CTCF_ChIP_200K_filterdup.pileup.bdg --extsize 254
#macs2 pileup -i CTCF_Control_200K_filterdup.bed -B --extsize 127 -o d_bg.bdg
#macs2 pileup -i CTCF_Control_200K_filterdup.bed -B --extsize 500 -o 1k_bg.bdg
#macs2 bdgopt -i 1k_bg.bdg -m multiply -p 0.254 -o 1k_bg_norm.bdg
#macs2 pileup -i CTCF_Control_200K_filterdup.bed -B --extsize 5000 -o 10k_bg.bdg
#macs2 bdgopt -i 1k_bg.bdg -m multiply -p 0.0254 -o 1k_bg_norm.bdg
#macs2 bdgcmp -m max -t 1k_bg_norm.bdg -c 10k_bg_norm.bdg -o 1k_10k_bg_norm.bdg
#macs2 bdgcmp -m max -t 1k_10k_bg_norm.bdg -c d_bg.bdg -o d_1k_10k_bg_norm.bdg
#macs2 bdgopt -i d_1k_10k_bg_norm.bdg -m max -p .0188023 -o local_bias_raw.bdg
#macs2 bdgopt -i local_bias_raw.bdg -m multiply -p .99858 -o local_lambda.bdg
#macs2 bdgcmp -t CTCF_ChIP_200K_filterdup.pileup.bdg -c local_lambda.bdg -m qpois -o CTCF_ChIP_200K_qvalue.bdg
#macs2 bdgbroadcall -i CTCF_ChIP_200K_qvalue.bdg -c 1.301 -l 245 -g 100 -o CTCF_ChIP_200K_peaks.bed
#or& for narrow peaks:
#macs2 bdgpeakcall -i CTCF_ChIP_200K_qvalue.bdg -c 1.301 -l 245 -g 100 -o CTCF_ChIP_200K_peaks.bed
def callPeaks(data):
    signal = data[0]
    signal_path = data[1]
    control = data[2]
    control_path = data[3]
    norm_factor = data[4]
    tmp_dir = "/data/mazurovev/tmp_peaks/tmp_call_peaks_for_" + signal
    os.mkdir(tmp_dir)
    print(signal)
    try:
        output = subprocess.check_output("macs2 filterdup -i " + signal_path + signal + ".bed" + " --keep-dup=1 -o " + tmp_dir + "/" + signal + "_filterdup.bed", shell=True, stderr=subprocess.STDOUT).decode()
        m = re.match(r".+tags after filtering in alignment file: (\d+).+", output, re.MULTILINE|re.DOTALL)
        signal_reads_count = m.group(1)
        
        output = subprocess.check_output("macs2 filterdup -i " + control_path + control + ".bed" + " --keep-dup=1 -o " + tmp_dir + "/" + control + "_filterdup.bed", shell=True, stderr=subprocess.STDOUT).decode()
        m = re.match(r".+tags after filtering in alignment file: (\d+).+", output, re.MULTILINE|re.DOTALL)
        control_reads_count = m.group(1)
        
        output = subprocess.check_output("macs2 predictd -i " + tmp_dir + "/" + signal + "_filterdup.bed" + " -g hs -m 5 50", shell=True, stderr=subprocess.STDOUT).decode()
        m = re.match(r".+predicted fragment length is (\d+).+", output, re.MULTILINE|re.DOTALL)
        extsize = m.group(1)
        
        output = subprocess.check_output("macs2 pileup -i " + tmp_dir + "/" + signal + "_filterdup.bed" + " -f BED -o " + tmp_dir + "/" + signal + "_filterdup.pileup.bdg --extsize " + extsize, shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 pileup -i " + tmp_dir + "/" + control + "_filterdup.bed" + " -B -f BED --extsize " + str(int(extsize)//2) + " -o " + tmp_dir + "/" + control + "_d_bg.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 pileup -i " + tmp_dir + "/" + control + "_filterdup.bed" + " -B -f BED --extsize 500 -o " + tmp_dir + "/" + control + "_1k_bg.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgopt -i " + tmp_dir + "/" + control + "_1k_bg.bdg" + " -m multiply -p " + str(int(extsize)/1000) + " -o " + tmp_dir + "/" + control + "_1k_bg_norm.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 pileup -i " + tmp_dir + "/" + control + "_filterdup.bed" + " -B -f BED --extsize 5000 -o " + tmp_dir + "/" + control + "_10k_bg.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgopt -i " + tmp_dir + "/" + control + "_10k_bg.bdg" + " -m multiply -p " + str(int(extsize)/10000) + " -o " + tmp_dir + "/" + control + "_10k_bg_norm.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        genome_bg = int(control_reads_count)*int(extsize)/2900000000
        
        output = subprocess.check_output("macs2 bdgcmp -m max -t " + tmp_dir + "/" + control + "_1k_bg_norm.bdg" + " -c " + tmp_dir + "/" + control + "_10k_bg_norm.bdg" + " -o " + tmp_dir + "/" + control + "_1k_10k_bg_norm.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgcmp -m max -t " + tmp_dir + "/" + control + "_1k_10k_bg_norm.bdg" + " -c " + tmp_dir + "/" + control + "_d_bg.bdg" + " -o " + tmp_dir + "/" + control + "_d_1k_10k_bg_norm.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgopt -i " + tmp_dir + "/" + control + "_d_1k_10k_bg_norm.bdg" + " -m max -p " + str(genome_bg) + " -o " + tmp_dir + "/" + control + "_local_bias_raw.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgopt -i " + tmp_dir + "/" + control + "_local_bias_raw.bdg" + " -m multiply -p " + str(norm_factor) + " -o " + tmp_dir + "/" + control + "_local_lambda.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        output = subprocess.check_output("macs2 bdgcmp -t " + tmp_dir + "/" + signal + "_filterdup.pileup.bdg" + " -c " + tmp_dir + "/" + control + "_local_lambda.bdg -m qpois -p 1" + " -o " + tmp_dir + "/" + signal + "_qvalue.bdg", shell=True, stderr=subprocess.STDOUT).decode()
        
        #broad or narrow peaks
        #output = subprocess.check_output("macs2 bdgbroadcall -i " + tmp_dir + "/" + signal + "_qvalue.bdg" + " -c 1.301 " + " -o " + signal_path + signal + "_peaks.bed", shell=True, stderr=subprocess.STDOUT).decode()
        output = subprocess.check_output("macs2 bdgpeakcall -i " + tmp_dir + "/" + signal + "_qvalue.bdg" + " -c 1.301 -l " + extsize + " -o " + signal_path + signal + "_narrow_peaks.bed", shell=True, stderr=subprocess.STDOUT).decode()
        print("done " + signal)
    except subprocess.CalledProcessError as e:
        output = e.output.decode()
        
    #shutil.rmtree(tmp_dir)
    return output

# %%
#TODO: попробовать другой broad_cutoff?
def call_peaks_macs2(data):
    signal = data[0]
    signal_path = data[1]
    control = data[2]
    control_path = data[3]
    norm_factor = data[4]
    print("macs2 callpeak --outdir " + signal_path + " -t " + signal_path + signal + ".bed" + 
                                         " -c " + control_path + control + ".bed" + 
                                         " -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n " + signal + " --ratio " + str(norm_factor))
    try:
        output = subprocess.check_output("macs2 callpeak --outdir " + signal_path + " -t " + signal_path + signal + ".bed" + 
                                         " -c " + control_path + control + ".bed" + 
                                         " -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n " + signal + " --ratio " + str(norm_factor), shell=True, stderr=subprocess.STDOUT).decode()
    except subprocess.CalledProcessError as e:
        output = e.output.decode()
        
    #shutil.rmtree(tmp_dir)
    return output

# %%
data = []
for index, row in d.iterrows():
    if(row['Experiment target'] == 'H3K27me3-human'):
        signal_path = "/data/mazurovev/" + row['Experiment target'].split('-')[0] + "/" + row['Biosample term id'] + "/"
        control_path = "/data/mazurovev/controls/"
        data.append((row['File accession'], signal_path, row['Control'], control_path, row['norm_factor']))

# %%
pool = Pool(processes=10)
outputs = pool.map(call_peaks_macs2, data)

pool.close()
pool.join()
# Out:
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002107/ -t /data/mazurovev/H3K27me3/UBERON:0002107/ENCFF457HGI.bed -c /data/mazurovev/controls/ENCFF964MSO.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF457HGI --ratio 0.761293
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002327/ -t /data/mazurovev/H3K27me3/CL:0002327/ENCFF015OVW.bed -c /data/mazurovev/controls/ENCFF801RTD.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF015OVW --ratio 0.3841786
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002369/ -t /data/mazurovev/H3K27me3/UBERON:0002369/ENCFF546HYL.bed -c /data/mazurovev/controls/ENCFF237BVB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF546HYL --ratio 0.8439027
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000992/ -t /data/mazurovev/H3K27me3/UBERON:0000992/ENCFF186TYR.bed -c /data/mazurovev/controls/ENCFF791PRR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF186TYR --ratio -1.0
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000842/ -t /data/mazurovev/H3K27me3/CL:0000842/ENCFF294WAV.bed -c /data/mazurovev/controls/ENCFF738UVB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF294WAV --ratio 0.44228370000000006
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000182/ -t /data/mazurovev/H3K27me3/CL:0000182/ENCFF208KVX.bed -c /data/mazurovev/controls/ENCFF248XON.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF208KVX --ratio 0.6577142
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000103/ -t /data/mazurovev/H3K27me3/CL:0000103/ENCFF122QYC.bed -c /data/mazurovev/controls/ENCFF956GLJ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF122QYC --ratio 0.5805701
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001515/ -t /data/mazurovev/H3K27me3/UBERON:0001515/ENCFF156BTT.bed -c /data/mazurovev/controls/ENCFF924RQL.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF156BTT --ratio 0.4023739
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002784/ -t /data/mazurovev/H3K27me3/EFO:0002784/ENCFF796DDM.bed -c /data/mazurovev/controls/ENCFF094HMB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF796DDM --ratio 0.8409698
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0001187/ -t /data/mazurovev/H3K27me3/EFO:0001187/ENCFF247LXA.bed -c /data/mazurovev/controls/ENCFF255TUT.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF247LXA --ratio 0.42088809999999993
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002784/ -t /data/mazurovev/H3K27me3/EFO:0002784/ENCFF927XRX.bed -c /data/mazurovev/controls/ENCFF094HMB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF927XRX --ratio 0.6264198000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002327/ -t /data/mazurovev/H3K27me3/CL:0002327/ENCFF843LLA.bed -c /data/mazurovev/controls/ENCFF801RTD.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF843LLA --ratio 0.24923939999999997
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002084/ -t /data/mazurovev/H3K27me3/UBERON:0002084/ENCFF228ZGV.bed -c /data/mazurovev/controls/ENCFF623DTG.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF228ZGV --ratio 0.7299188
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001159/ -t /data/mazurovev/H3K27me3/UBERON:0001159/ENCFF607WIJ.bed -c /data/mazurovev/controls/ENCFF999JOG.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF607WIJ --ratio 0.2733846
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002084/ -t /data/mazurovev/H3K27me3/UBERON:0002084/ENCFF552NGA.bed -c /data/mazurovev/controls/ENCFF676AXV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF552NGA --ratio 0.4760474
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:1001606/ -t /data/mazurovev/H3K27me3/CL:1001606/ENCFF860CKZ.bed -c /data/mazurovev/controls/ENCFF270SFZ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF860CKZ --ratio 1.389024
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0005723/ -t /data/mazurovev/H3K27me3/EFO:0005723/ENCFF122SGX.bed -c /data/mazurovev/controls/ENCFF027OMV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF122SGX --ratio 0.4788635
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0011907/ -t /data/mazurovev/H3K27me3/UBERON:0011907/ENCFF144WWG.bed -c /data/mazurovev/controls/ENCFF634UHG.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF144WWG --ratio 1.001636
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001496/ -t /data/mazurovev/H3K27me3/UBERON:0001496/ENCFF411QLO.bed -c /data/mazurovev/controls/ENCFF893ZJC.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF411QLO --ratio 0.7870301
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001150/ -t /data/mazurovev/H3K27me3/UBERON:0001150/ENCFF943RGA.bed -c /data/mazurovev/controls/ENCFF228XSQ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF943RGA --ratio 1.022297
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001515/ -t /data/mazurovev/H3K27me3/UBERON:0001515/ENCFF786XOM.bed -c /data/mazurovev/controls/ENCFF924RQL.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF786XOM --ratio 0.4387103
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000948/ -t /data/mazurovev/H3K27me3/UBERON:0000948/ENCFF237BOS.bed -c /data/mazurovev/controls/ENCFF589TFO.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF237BOS --ratio 1.16537
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000182/ -t /data/mazurovev/H3K27me3/CL:0000182/ENCFF523TBZ.bed -c /data/mazurovev/controls/ENCFF248XON.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF523TBZ --ratio 1.094364
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000127/ -t /data/mazurovev/H3K27me3/CL:0000127/ENCFF442ZRV.bed -c /data/mazurovev/controls/ENCFF639TYV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF442ZRV --ratio 0.1781213
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:1001606/ -t /data/mazurovev/H3K27me3/CL:1001606/ENCFF770OXM.bed -c /data/mazurovev/controls/ENCFF178GZR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF770OXM --ratio 1.4591120000000002
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001211/ -t /data/mazurovev/H3K27me3/UBERON:0001211/ENCFF337ODD.bed -c /data/mazurovev/controls/ENCFF110BDU.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF337ODD --ratio 0.8110515
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0001187/ -t /data/mazurovev/H3K27me3/EFO:0001187/ENCFF785SBQ.bed -c /data/mazurovev/controls/ENCFF255TUT.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF785SBQ --ratio 0.1663351
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0005723/ -t /data/mazurovev/H3K27me3/EFO:0005723/ENCFF943RTB.bed -c /data/mazurovev/controls/ENCFF027OMV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF943RTB --ratio 0.4685009
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0011907/ -t /data/mazurovev/H3K27me3/UBERON:0011907/ENCFF234GEW.bed -c /data/mazurovev/controls/ENCFF634UHG.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF234GEW --ratio 0.8358766
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000103/ -t /data/mazurovev/H3K27me3/CL:0000103/ENCFF399QGQ.bed -c /data/mazurovev/controls/ENCFF956GLJ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF399QGQ --ratio 0.4174960999999999
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000127/ -t /data/mazurovev/H3K27me3/CL:0000127/ENCFF757AUJ.bed -c /data/mazurovev/controls/ENCFF639TYV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF757AUJ --ratio 0.338854
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002046/ -t /data/mazurovev/H3K27me3/UBERON:0002046/ENCFF201WBT.bed -c /data/mazurovev/controls/ENCFF464KVS.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF201WBT --ratio 0.7573099
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:1001606/ -t /data/mazurovev/H3K27me3/CL:1001606/ENCFF252XIN.bed -c /data/mazurovev/controls/ENCFF444OBR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF252XIN --ratio 1.243514
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0004648/ -t /data/mazurovev/H3K27me3/UBERON:0004648/ENCFF131KLD.bed -c /data/mazurovev/controls/ENCFF255WXC.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF131KLD --ratio 0.4564688
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:1001606/ -t /data/mazurovev/H3K27me3/CL:1001606/ENCFF020YIZ.bed -c /data/mazurovev/controls/ENCFF178GZR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF020YIZ --ratio 1.529778
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002046/ -t /data/mazurovev/H3K27me3/UBERON:0002046/ENCFF249BFZ.bed -c /data/mazurovev/controls/ENCFF464KVS.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF249BFZ --ratio 1.117332
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0011907/ -t /data/mazurovev/H3K27me3/UBERON:0011907/ENCFF650KVU.bed -c /data/mazurovev/controls/ENCFF287TUT.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF650KVU --ratio 0.5857286
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000945/ -t /data/mazurovev/H3K27me3/UBERON:0000945/ENCFF582NZD.bed -c /data/mazurovev/controls/ENCFF904DBV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF582NZD --ratio 0.2650356
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002372/ -t /data/mazurovev/H3K27me3/CL:0002372/ENCFF287IGX.bed -c /data/mazurovev/controls/ENCFF408COK.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF287IGX --ratio 0.9450738000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:1001606/ -t /data/mazurovev/H3K27me3/CL:1001606/ENCFF108CVW.bed -c /data/mazurovev/controls/ENCFF270SFZ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF108CVW --ratio 1.5014809999999998
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000842/ -t /data/mazurovev/H3K27me3/CL:0000842/ENCFF193OFZ.bed -c /data/mazurovev/controls/ENCFF738UVB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF193OFZ --ratio 0.7252854999999999
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002048/ -t /data/mazurovev/H3K27me3/UBERON:0002048/ENCFF048FDD.bed -c /data/mazurovev/controls/ENCFF894ZBD.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF048FDD --ratio 1.41337
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001150/ -t /data/mazurovev/H3K27me3/UBERON:0001150/ENCFF048HZR.bed -c /data/mazurovev/controls/ENCFF644ZVV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF048HZR --ratio 0.6822184
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001150/ -t /data/mazurovev/H3K27me3/UBERON:0001150/ENCFF880JQE.bed -c /data/mazurovev/controls/ENCFF590RZJ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF880JQE --ratio 0.6490549
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:1001606/ -t /data/mazurovev/H3K27me3/CL:1001606/ENCFF079MUK.bed -c /data/mazurovev/controls/ENCFF444OBR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF079MUK --ratio 1.366901
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002048/ -t /data/mazurovev/H3K27me3/UBERON:0002048/ENCFF585KVQ.bed -c /data/mazurovev/controls/ENCFF562SIS.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF585KVQ --ratio 0.6356130999999999
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002240/ -t /data/mazurovev/H3K27me3/UBERON:0002240/ENCFF129QUW.bed -c /data/mazurovev/controls/ENCFF879WYG.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF129QUW --ratio 0.7060946
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0004648/ -t /data/mazurovev/H3K27me3/UBERON:0004648/ENCFF349LVZ.bed -c /data/mazurovev/controls/ENCFF144FKQ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF349LVZ --ratio 0.8523233
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0008367/ -t /data/mazurovev/H3K27me3/UBERON:0008367/ENCFF114URN.bed -c /data/mazurovev/controls/ENCFF636AYA.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF114URN --ratio 1.833651
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002518/ -t /data/mazurovev/H3K27me3/CL:0002518/ENCFF575FWP.bed -c /data/mazurovev/controls/ENCFF115YWW.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF575FWP --ratio 0.5737554
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0011907/ -t /data/mazurovev/H3K27me3/UBERON:0011907/ENCFF633HJH.bed -c /data/mazurovev/controls/ENCFF736RVR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF633HJH --ratio 1.115761
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002048/ -t /data/mazurovev/H3K27me3/UBERON:0002048/ENCFF728OZT.bed -c /data/mazurovev/controls/ENCFF555QPV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF728OZT --ratio 0.34328159999999996
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002067/ -t /data/mazurovev/H3K27me3/EFO:0002067/ENCFF190OWE.bed -c /data/mazurovev/controls/ENCFF829HZY.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF190OWE --ratio 0.45069209999999993
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000746/ -t /data/mazurovev/H3K27me3/CL:0000746/ENCFF083APJ.bed -c /data/mazurovev/controls/ENCFF120GPO.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF083APJ --ratio 1.0907280000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002518/ -t /data/mazurovev/H3K27me3/CL:0002518/ENCFF658MNZ.bed -c /data/mazurovev/controls/ENCFF115YWW.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF658MNZ --ratio 0.7631197
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001157/ -t /data/mazurovev/H3K27me3/UBERON:0001157/ENCFF066QNC.bed -c /data/mazurovev/controls/ENCFF509UCY.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF066QNC --ratio 0.5900404
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002067/ -t /data/mazurovev/H3K27me3/EFO:0002067/ENCFF692KQZ.bed -c /data/mazurovev/controls/ENCFF829HZY.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF692KQZ --ratio 0.3113598
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0001187/ -t /data/mazurovev/H3K27me3/EFO:0001187/ENCFF030HAG.bed -c /data/mazurovev/controls/ENCFF887ZEB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF030HAG --ratio 0.49192749999999996
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0008952/ -t /data/mazurovev/H3K27me3/UBERON:0008952/ENCFF673UOT.bed -c /data/mazurovev/controls/ENCFF981WUC.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF673UOT --ratio 0.9402872999999999
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0001187/ -t /data/mazurovev/H3K27me3/EFO:0001187/ENCFF394DQA.bed -c /data/mazurovev/controls/ENCFF887ZEB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF394DQA --ratio 0.36553109999999994
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0005904/ -t /data/mazurovev/H3K27me3/EFO:0005904/ENCFF421HFM.bed -c /data/mazurovev/controls/ENCFF043XTH.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF421HFM --ratio 0.8442357
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002372/ -t /data/mazurovev/H3K27me3/CL:0002372/ENCFF864QHJ.bed -c /data/mazurovev/controls/ENCFF408COK.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF864QHJ --ratio 0.3668172
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0005904/ -t /data/mazurovev/H3K27me3/EFO:0005904/ENCFF250WQM.bed -c /data/mazurovev/controls/ENCFF043XTH.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF250WQM --ratio 0.3669206
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000945/ -t /data/mazurovev/H3K27me3/UBERON:0000945/ENCFF500NQH.bed -c /data/mazurovev/controls/ENCFF386HHN.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF500NQH --ratio 1.317884
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0001196/ -t /data/mazurovev/H3K27me3/EFO:0001196/ENCFF825OWT.bed -c /data/mazurovev/controls/ENCFF841PLU.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF825OWT --ratio 0.8793098
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0007950/ -t /data/mazurovev/H3K27me3/EFO:0007950/ENCFF862WYK.bed -c /data/mazurovev/controls/ENCFF754UFV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF862WYK --ratio 0.1559884
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002369/ -t /data/mazurovev/H3K27me3/UBERON:0002369/ENCFF732UZB.bed -c /data/mazurovev/controls/ENCFF962WPS.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF732UZB --ratio 0.38225
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0003042/ -t /data/mazurovev/H3K27me3/EFO:0003042/ENCFF830PVE.bed -c /data/mazurovev/controls/ENCFF236MNB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF830PVE --ratio 0.5540645000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000746/ -t /data/mazurovev/H3K27me3/CL:0000746/ENCFF407XPY.bed -c /data/mazurovev/controls/ENCFF120GPO.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF407XPY --ratio 1.028216
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000515/ -t /data/mazurovev/H3K27me3/CL:0000515/ENCFF462BRB.bed -c /data/mazurovev/controls/ENCFF298NLV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF462BRB --ratio 1.533635
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0003042/ -t /data/mazurovev/H3K27me3/EFO:0003042/ENCFF382GPJ.bed -c /data/mazurovev/controls/ENCFF572GEP.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF382GPJ --ratio 0.6593793000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000995/ -t /data/mazurovev/H3K27me3/UBERON:0000995/ENCFF538OSP.bed -c /data/mazurovev/controls/ENCFF851BYG.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF538OSP --ratio 1.267707
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000515/ -t /data/mazurovev/H3K27me3/CL:0000515/ENCFF232HUV.bed -c /data/mazurovev/controls/ENCFF298NLV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF232HUV --ratio 0.9443546
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0001196/ -t /data/mazurovev/H3K27me3/EFO:0001196/ENCFF868WTE.bed -c /data/mazurovev/controls/ENCFF841PLU.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF868WTE --ratio 1.4093870000000002
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002106/ -t /data/mazurovev/H3K27me3/UBERON:0002106/ENCFF558UBX.bed -c /data/mazurovev/controls/ENCFF259EKT.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF558UBX --ratio 2.120151
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000945/ -t /data/mazurovev/H3K27me3/UBERON:0000945/ENCFF192EMA.bed -c /data/mazurovev/controls/ENCFF966QLG.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF192EMA --ratio 0.2119364
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000746/ -t /data/mazurovev/H3K27me3/CL:0000746/ENCFF207UDF.bed -c /data/mazurovev/controls/ENCFF504HBF.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF207UDF --ratio 0.6270346
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0003042/ -t /data/mazurovev/H3K27me3/EFO:0003042/ENCFF310SBN.bed -c /data/mazurovev/controls/ENCFF393RKZ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF310SBN --ratio 0.5242826
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001211/ -t /data/mazurovev/H3K27me3/UBERON:0001211/ENCFF720LVW.bed -c /data/mazurovev/controls/ENCFF591VCF.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF720LVW --ratio 1.20487
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0003042/ -t /data/mazurovev/H3K27me3/EFO:0003042/ENCFF596SHE.bed -c /data/mazurovev/controls/ENCFF236MNB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF596SHE --ratio 0.7492808000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000192/ -t /data/mazurovev/H3K27me3/CL:0000192/ENCFF509JMC.bed -c /data/mazurovev/controls/ENCFF302IIT.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF509JMC --ratio 1.2637639999999999
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0003042/ -t /data/mazurovev/H3K27me3/EFO:0003042/ENCFF083QQZ.bed -c /data/mazurovev/controls/ENCFF393RKZ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF083QQZ --ratio 0.37017540000000004
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000746/ -t /data/mazurovev/H3K27me3/CL:0000746/ENCFF231YIP.bed -c /data/mazurovev/controls/ENCFF504HBF.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF231YIP --ratio 0.6994156
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002106/ -t /data/mazurovev/H3K27me3/UBERON:0002106/ENCFF708NMK.bed -c /data/mazurovev/controls/ENCFF969DRM.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF708NMK --ratio 0.49290200000000006
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002067/ -t /data/mazurovev/H3K27me3/EFO:0002067/ENCFF915XIL.bed -c /data/mazurovev/controls/ENCFF355SGP.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF915XIL --ratio 0.2175595
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001323/ -t /data/mazurovev/H3K27me3/UBERON:0001323/ENCFF880MZS.bed -c /data/mazurovev/controls/ENCFF782HSW.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF880MZS --ratio 1.089528
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001159/ -t /data/mazurovev/H3K27me3/UBERON:0001159/ENCFF124DET.bed -c /data/mazurovev/controls/ENCFF718BTS.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF124DET --ratio 0.6846053000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000192/ -t /data/mazurovev/H3K27me3/CL:0000192/ENCFF327WQJ.bed -c /data/mazurovev/controls/ENCFF302IIT.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF327WQJ --ratio 0.9454577
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000945/ -t /data/mazurovev/H3K27me3/UBERON:0000945/ENCFF189FFP.bed -c /data/mazurovev/controls/ENCFF419ELL.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF189FFP --ratio 0.5889854999999999
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0005719/ -t /data/mazurovev/H3K27me3/EFO:0005719/ENCFF960YXZ.bed -c /data/mazurovev/controls/ENCFF056BZA.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF960YXZ --ratio 1.4901659999999999
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002074/ -t /data/mazurovev/H3K27me3/EFO:0002074/ENCFF347INE.bed -c /data/mazurovev/controls/ENCFF607ZQL.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF347INE --ratio 0.6693646
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0007950/ -t /data/mazurovev/H3K27me3/EFO:0007950/ENCFF371CJE.bed -c /data/mazurovev/controls/ENCFF754UFV.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF371CJE --ratio 0.2085539
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002067/ -t /data/mazurovev/H3K27me3/EFO:0002067/ENCFF330YFF.bed -c /data/mazurovev/controls/ENCFF355SGP.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF330YFF --ratio 0.403469
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0003042/ -t /data/mazurovev/H3K27me3/EFO:0003042/ENCFF748KOZ.bed -c /data/mazurovev/controls/ENCFF572GEP.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF748KOZ --ratio 1.126117
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/NTR:0000711/ -t /data/mazurovev/H3K27me3/NTR:0000711/ENCFF951AJL.bed -c /data/mazurovev/controls/ENCFF175BOB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF951AJL --ratio 0.6656618000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002553/ -t /data/mazurovev/H3K27me3/CL:0002553/ENCFF535LEC.bed -c /data/mazurovev/controls/ENCFF681UKF.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF535LEC --ratio 0.5474273000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000473/ -t /data/mazurovev/H3K27me3/UBERON:0000473/ENCFF533REZ.bed -c /data/mazurovev/controls/ENCFF054TED.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF533REZ --ratio 1.1382
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002328/ -t /data/mazurovev/H3K27me3/CL:0002328/ENCFF425HDW.bed -c /data/mazurovev/controls/ENCFF682GMA.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF425HDW --ratio 0.6348666000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0005719/ -t /data/mazurovev/H3K27me3/EFO:0005719/ENCFF813CKH.bed -c /data/mazurovev/controls/ENCFF056BZA.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF813CKH --ratio 1.398993
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002784/ -t /data/mazurovev/H3K27me3/EFO:0002784/ENCFF175YYN.bed -c /data/mazurovev/controls/ENCFF684NLR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF175YYN --ratio 0.8666805000000001
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002328/ -t /data/mazurovev/H3K27me3/CL:0002328/ENCFF518FAE.bed -c /data/mazurovev/controls/ENCFF682GMA.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF518FAE --ratio 0.7422186
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0008952/ -t /data/mazurovev/H3K27me3/UBERON:0008952/ENCFF316LIQ.bed -c /data/mazurovev/controls/ENCFF163YFX.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF316LIQ --ratio 1.367473
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002327/ -t /data/mazurovev/H3K27me3/CL:0002327/ENCFF520NCF.bed -c /data/mazurovev/controls/ENCFF163IHR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF520NCF --ratio 0.3776231
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002784/ -t /data/mazurovev/H3K27me3/EFO:0002784/ENCFF231DJN.bed -c /data/mazurovev/controls/ENCFF684NLR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF231DJN --ratio 1.227264
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002106/ -t /data/mazurovev/H3K27me3/UBERON:0002106/ENCFF202EUA.bed -c /data/mazurovev/controls/ENCFF608SQR.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF202EUA --ratio 0.7545149
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001323/ -t /data/mazurovev/H3K27me3/UBERON:0001323/ENCFF201JXX.bed -c /data/mazurovev/controls/ENCFF925HTZ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF201JXX --ratio 0.7536111
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0000995/ -t /data/mazurovev/H3K27me3/UBERON:0000995/ENCFF798ITI.bed -c /data/mazurovev/controls/ENCFF326UUS.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF798ITI --ratio 0.9073708
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002084/ -t /data/mazurovev/H3K27me3/UBERON:0002084/ENCFF404YFJ.bed -c /data/mazurovev/controls/ENCFF639VKM.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF404YFJ --ratio 0.3856112
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001496/ -t /data/mazurovev/H3K27me3/UBERON:0001496/ENCFF741NYO.bed -c /data/mazurovev/controls/ENCFF299AOC.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF741NYO --ratio 0.7162651
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/EFO:0002074/ -t /data/mazurovev/H3K27me3/EFO:0002074/ENCFF127CPB.bed -c /data/mazurovev/controls/ENCFF607ZQL.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF127CPB --ratio 0.6745229
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/NTR:0000711/ -t /data/mazurovev/H3K27me3/NTR:0000711/ENCFF219YIY.bed -c /data/mazurovev/controls/ENCFF175BOB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF219YIY --ratio 0.5840823
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000062/ -t /data/mazurovev/H3K27me3/CL:0000062/ENCFF318IMH.bed -c /data/mazurovev/controls/ENCFF535QXZ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF318IMH --ratio 0.1739588
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001157/ -t /data/mazurovev/H3K27me3/UBERON:0001157/ENCFF403ZNV.bed -c /data/mazurovev/controls/ENCFF742DCE.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF403ZNV --ratio 1.134496
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0006631/ -t /data/mazurovev/H3K27me3/UBERON:0006631/ENCFF123VMN.bed -c /data/mazurovev/controls/ENCFF524KQP.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF123VMN --ratio 0.9665134
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0000062/ -t /data/mazurovev/H3K27me3/CL:0000062/ENCFF798RLD.bed -c /data/mazurovev/controls/ENCFF535QXZ.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF798RLD --ratio 0.5675741
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0001157/ -t /data/mazurovev/H3K27me3/UBERON:0001157/ENCFF484XQD.bed -c /data/mazurovev/controls/ENCFF665FWN.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF484XQD --ratio 0.8630815999999999
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0002046/ -t /data/mazurovev/H3K27me3/UBERON:0002046/ENCFF924JKS.bed -c /data/mazurovev/controls/ENCFF079PQP.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF924JKS --ratio 0.5141673
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/CL:0002553/ -t /data/mazurovev/H3K27me3/CL:0002553/ENCFF834MYP.bed -c /data/mazurovev/controls/ENCFF681UKF.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF834MYP --ratio 0.6331863
# macs2 callpeak --outdir /data/mazurovev/H3K27me3/UBERON:0006920/ -t /data/mazurovev/H3K27me3/UBERON:0006920/ENCFF245SNK.bed -c /data/mazurovev/controls/ENCFF305KDB.bed -f BED --broad --broad-cutoff 0.1 -g 2.9e9 -q 0.05 -n ENCFF245SNK --ratio 1.120637

# %%
#========================

# %%
#callpeak -t ENCFF318IMH.bed -c /data/mazurovev/controls/ENCFF535QXZ.bed -f BED --broad -g 2.9e9 -q 0.05 -n macs2_original --broad-cutoff 0.05 --ratio 0.1739588
